# %% [markdown]
# # PostgreSQL: use sql magic %sql
# * pip install ipython-sql
# * doc: https://pypi.org/project/ipython-sql/

# %% [markdown]
# ---
# * author:  [Prasert Kanawattanachai](prasert.k@chula.ac.th)
# * YouTube: https://www.youtube.com/prasertcbs
# * [Chulalongkorn Business School](https://www.cbs.chula.ac.th/en/)
# ---

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('bgHPGiE0rkg', width=720, height=405)

# %%
import pandas as pd
import psycopg2 # postgresql db driver

# %%
print(f'pandas    version: {pd.__version__}')
print(f'psycopg2  version: {psycopg2.__version__}')
# Out:
# pandas    version: 1.0.3
# psycopg2  version: 2.8.5 (dt dec pq3 ext lo64)

# %%
# %load_ext sql

# %% [markdown]
# ## PostgresSQL connection

# %%
import getpass
host='192.168.211.137'
port=5432
dbname='disney'

user=input('user name: ')
pwd=getpass.getpass('password: ')
# Out:
# user name:  postgres
# password:  ······

# %% [markdown]
# ### connection string
# * sqlalchemy connection string format
# * doc: https://docs.sqlalchemy.org/en/13/core/engines.html

# %%
connection_string=f'postgresql+psycopg2://{user}:{pwd}@{host}:{port}/{dbname}'

# %%
connection_string
# Out:
# 'postgresql+psycopg2://postgres:banana@192.168.211.137:5432/disney'

# %%
# %sql postgresql+psycopg2://postgres:banana@192.168.211.137:5432/disney

# %%
# %sql select * from movie_gross limit 10;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 10 rows affected.
# [('amy', datetime.date(1981, 3, 20), 'Drama', None, 0, 0),
#  ('honey i blew up the kid', datetime.date(1992, 7, 17), 'Comedy', 'PG', 58662452, 119162518),
#  ('a stranger among us', datetime.date(1992, 7, 17), 'Drama', 'PG-13', 12282994, 24950752),
#  ("a gun in betty lou's handbag", datetime.date(1992, 8, 21), None, 'PG-13', 3591460, 7295423),
#  ('captain ron', datetime.date(1992, 9, 18), 'Comedy', 'PG-13', 22518097, 45741576),
#  ('sarafina!', datetime.date(1992, 9, 18), 'Drama', 'PG-13', 7306242, 14841352),
#  ('innocent blood', datetime.date(1992, 9, 25), 'Horror', 'R', 4877567, 9907922),
#  ('the mighty ducks', datetime.date(1992, 10, 2), 'Comedy', 'PG', 50752337, 103120810),
#  ('1492: conquest of paradise', datetime.date(1992, 10, 9), 'Adventure', 'PG-13', 7099531, 14421454),
#  ('consenting adults', datetime.date(1992, 10, 16), 'Drama', 'R', 21591728, 43859823)]

# %%
# %sql $connection_string

# %%
# %sql select * from movie_gross limit 5;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 5 rows affected.
# [('amy', datetime.date(1981, 3, 20), 'Drama', None, 0, 0),
#  ('honey i blew up the kid', datetime.date(1992, 7, 17), 'Comedy', 'PG', 58662452, 119162518),
#  ('a stranger among us', datetime.date(1992, 7, 17), 'Drama', 'PG-13', 12282994, 24950752),
#  ("a gun in betty lou's handbag", datetime.date(1992, 8, 21), None, 'PG-13', 3591460, 7295423),
#  ('captain ron', datetime.date(1992, 9, 18), 'Comedy', 'PG-13', 22518097, 45741576)]

# %%
# %sql select * from movie_gross limit 5;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 5 rows affected.
# [('amy', datetime.date(1981, 3, 20), 'Drama', None, 0, 0),
#  ('honey i blew up the kid', datetime.date(1992, 7, 17), 'Comedy', 'PG', 58662452, 119162518),
#  ('a stranger among us', datetime.date(1992, 7, 17), 'Drama', 'PG-13', 12282994, 24950752),
#  ("a gun in betty lou's handbag", datetime.date(1992, 8, 21), None, 'PG-13', 3591460, 7295423),
#  ('captain ron', datetime.date(1992, 9, 18), 'Comedy', 'PG-13', 22518097, 45741576)]

# %%
# %%sql
# select * from movie_gross limit 5;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 5 rows affected.
# [('amy', datetime.date(1981, 3, 20), 'Drama', None, 0, 0),
#  ('honey i blew up the kid', datetime.date(1992, 7, 17), 'Comedy', 'PG', 58662452, 119162518),
#  ('a stranger among us', datetime.date(1992, 7, 17), 'Drama', 'PG-13', 12282994, 24950752),
#  ("a gun in betty lou's handbag", datetime.date(1992, 8, 21), None, 'PG-13', 3591460, 7295423),
#  ('captain ron', datetime.date(1992, 9, 18), 'Comedy', 'PG-13', 22518097, 45741576)]

# %%
# %%sql
# select *
#     from movie_gross
#     limit 5;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 5 rows affected.
# [('amy', datetime.date(1981, 3, 20), 'Drama', None, 0, 0),
#  ('honey i blew up the kid', datetime.date(1992, 7, 17), 'Comedy', 'PG', 58662452, 119162518),
#  ('a stranger among us', datetime.date(1992, 7, 17), 'Drama', 'PG-13', 12282994, 24950752),
#  ("a gun in betty lou's handbag", datetime.date(1992, 8, 21), None, 'PG-13', 3591460, 7295423),
#  ('captain ron', datetime.date(1992, 9, 18), 'Comedy', 'PG-13', 22518097, 45741576)]

# %%
# %%sql
# select * from pg_catalog.pg_tables
#     where schemaname != 'pg_catalog' and schemaname != 'information_schema';
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 5 rows affected.
# [('public', 'director', 'postgres', None, False, False, False, False),
#  ('public', 'disney_char', 'postgres', None, False, False, False, False),
#  ('public', 'movie_gross', 'postgres', None, False, False, False, False),
#  ('public', 'revenue', 'postgres', None, False, False, False, False),
#  ('public', 'voice_actor', 'postgres', None, False, False, False, False)]

# %%
# %%sql
# select table_catalog, table_name, column_name, data_type
#     from information_schema.columns
#     where table_name='movie_gross'
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 6 rows affected.
# [('disney', 'movie_gross', 'movie_title', 'text'),
#  ('disney', 'movie_gross', 'release_date', 'date'),
#  ('disney', 'movie_gross', 'genre', 'text'),
#  ('disney', 'movie_gross', 'mpaa_rating', 'text'),
#  ('disney', 'movie_gross', 'total_gross', 'bigint'),
#  ('disney', 'movie_gross', 'inflation_adjusted_gross', 'bigint')]

# %% [markdown]
# ## psql \ command

# %%
# pip install pgspecial

# %%
# %sql \l
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 7 rows affected.
# [('covid19', 'postgres', 'UTF8', 'en_US.utf8', 'en_US.utf8', None),
#  ('demo', 'postgres', 'UTF8', 'en_US.utf8', 'en_US.utf8', None),
#  ('disney', 'postgres', 'UTF8', 'en_US.utf8', 'en_US.utf8', None),
#  ('foody', 'postgres', 'UTF8', 'en_US.utf8', 'en_US.utf8', None),
#  ('postgres', 'postgres', 'UTF8', 'en_US.utf8', 'en_US.utf8', None),
#  ('template0',
#   'postgres',
#   'UTF8',
#   'en_US.utf8',
#   'en_US.utf8',
#   '=c/postgres\npostgres=CTc/postgres'),
#  ('template1',
#   'postgres',
#   'UTF8',
#   'en_US.utf8',
#   'en_US.utf8',
#   '=c/postgres\npostgres=CTc/postgres')]

# %%
# %sql \d
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 7 rows affected.
# [('public', 'director', 'table', 'postgres'),
#  ('public', 'disney_char', 'table', 'postgres'),
#  ('public', 'movie_gross', 'table', 'postgres'),
#  ('public', 'revenue', 'table', 'postgres'),
#  ('public', 'voice_actor', 'table', 'postgres'),
#  ('public', 'vw_action', 'view', 'postgres'),
#  ('public', 'vw_adventure', 'view', 'postgres')]

# %%
# %sql \d movie_gross
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 6 rows affected.
# [['movie_title', 'text', ''],
#  ['release_date', 'date', ''],
#  ['genre', 'text', ''],
#  ['mpaa_rating', 'text', ''],
#  ['total_gross', 'bigint', ''],
#  ['inflation_adjusted_gross', 'bigint', '']]

# %% [markdown]
# ## %sql (single line) vs %%sql (multi-line)

# %%
# %sql select * from movie_gross limit 3;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 3 rows affected.
# [('amy', datetime.date(1981, 3, 20), 'Drama', None, 0, 0),
#  ('honey i blew up the kid', datetime.date(1992, 7, 17), 'Comedy', 'PG', 58662452, 119162518),
#  ('a stranger among us', datetime.date(1992, 7, 17), 'Drama', 'PG-13', 12282994, 24950752)]

# %%
# %%sql
# select * from movie_gross limit 3;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 3 rows affected.
# [('amy', datetime.date(1981, 3, 20), 'Drama', None, 0, 0),
#  ('honey i blew up the kid', datetime.date(1992, 7, 17), 'Comedy', 'PG', 58662452, 119162518),
#  ('a stranger among us', datetime.date(1992, 7, 17), 'Drama', 'PG-13', 12282994, 24950752)]

# %%
# %%sql
# select *
#     from movie_gross
#     where genre = 'Adventure'
#     limit 5;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 5 rows affected.
# [('1492: conquest of paradise', datetime.date(1992, 10, 9), 'Adventure', 'PG-13', 7099531, 14421454),
#  ('alive', datetime.date(1993, 1, 15), 'Adventure', 'R', 36299670, 73914543),
#  ('homeward bound: the incredible journey', datetime.date(1993, 2, 3), 'Adventure', 'G', 41833324, 85182343),
#  ('a far off place', datetime.date(1993, 3, 12), 'Adventure', 'PG', 12890752, 26248558),
#  ('the adventures of huck finn', datetime.date(1993, 4, 2), 'Adventure', 'PG', 24103594, 49080505)]

# %%
# %%sql
# select * from movie_gross
#     where extract(year from release_date)=2016
#     limit 5;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 5 rows affected.
# [('the finest hours', datetime.date(2016, 1, 29), 'Thriller/Suspense', 'PG', 27569558, 27569558),
#  ('zootopia', datetime.date(2016, 3, 4), 'Adventure', 'PG', 341268248, 341268248),
#  ('the jungle book', datetime.date(2016, 4, 15), 'Adventure', 'PG', 364001123, 364001123),
#  ('a beautiful planet', datetime.date(2016, 4, 29), 'Documentary', 'G', 7895708, 7895708),
#  ('captain america: civil war', datetime.date(2016, 5, 6), 'Action', 'PG-13', 408084349, 408084349)]

# %%
# %%sql
# drop view if exists vw_adventure;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# Done.
# []

# %%
# %%sql
# create view vw_adventure as
#     select * from movie_gross
#         where genre='Adventure';
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# Done.
# []

# %%
# %%sql
# select * from vw_adventure where total_gross > 100e6;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 52 rows affected.
# [('the lion king', datetime.date(1994, 6, 15), 'Adventure', 'G', 422780140, 761640898),
#  ('pocahontas', datetime.date(1995, 6, 10), 'Adventure', 'G', 141579773, 274370957),
#  ('toy story', datetime.date(1995, 11, 22), 'Adventure', 'G', 191796233, 370409631),
#  ('the hunchback of notre dame', datetime.date(1996, 6, 21), 'Adventure', 'G', 100138851, 190988799),
#  ('mulan', datetime.date(1998, 6, 19), 'Adventure', 'G', 120620254, 216807832),
#  ('armageddon', datetime.date(1998, 7, 1), 'Adventure', 'PG-13', 201578182, 362324957),
#  ("a bug's life", datetime.date(1998, 11, 20), 'Adventure', 'G', 162798565, 288981698),
#  ('tarzan', datetime.date(1999, 6, 16), 'Adventure', 'G', 171091819, 283900254),
#  ('toy story 2', datetime.date(1999, 11, 19), 'Adventure', 'G', 245852179, 404450426),
#  ('dinosaur', datetime.date(2000, 5, 19), 'Adventure', 'PG', 137748063, 215438985),
#  ('monsters, inc.', datetime.date(2001, 11, 2), 'Adventure', 'G', 289423425, 416073179),
#  ('lilo & stitch', datetime.date(2002, 6, 21), 'Adventure', 'PG', 145771527, 211506702),
#  ('finding nemo', datetime.date(2003, 5, 30), 'Adventure', 'G', 380529370, 518148559),
#  ('pirates of the caribbean: the curse o…', datetime.date(2003, 7, 9), 'Adventure', 'PG-13', 305411224, 426967926),
#  ('the incredibles', datetime.date(2004, 11, 5), 'Adventure', 'PG', 261441092, 354488708),
#  ('national treasure', datetime.date(2004, 11, 19), 'Adventure', 'PG', 173005002, 234069353),
#  ('chicken little', datetime.date(2005, 11, 4), 'Adventure', 'G', 135386665, 177954661),
#  ('the chronicles of narnia: the lion, t…', datetime.date(2005, 12, 9), 'Adventure', 'PG', 291710957, 381557539),
#  ('pirates of the caribbean: dead man’…', datetime.date(2006, 7, 7), 'Adventure', 'PG-13', 423315812, 544817142),
#  ('pirates of the caribbean: at world’…', datetime.date(2007, 5, 24), 'Adventure', 'PG-13', 309420425, 379129960),
#  ('national treasure 2: book of secrets', datetime.date(2007, 12, 21), 'Adventure', 'PG', 219961501, 267003525),
#  ('the chronicles of narnia: prince caspian', datetime.date(2008, 5, 16), 'Adventure', 'PG', 141621490, 166277038),
#  ('wall-e', datetime.date(2008, 6, 27), 'Adventure', 'G', 223808164, 262771918),
#  ('up', datetime.date(2009, 5, 29), 'Adventure', 'PG', 293004164, 329336681),
#  ('g-force', datetime.date(2009, 7, 24), 'Adventure', 'PG', 119436770, 134246932),
#  ('pirates of the caribbean: on stranger…', datetime.date(2011, 5, 20), 'Adventure', 'PG-13', 241063875, 256263359),
#  ('cars 2', datetime.date(2011, 6, 24), 'Adventure', 'G', 191450875, 203522177),
#  ('inside out', datetime.date(2015, 6, 19), 'Adventure', 'PG', 356461711, 356461711),
#  ('the good dinosaur', datetime.date(2015, 11, 25), 'Adventure', 'PG', 123087120, 123087120),
#  ('star wars ep. vii: the force awakens', datetime.date(2015, 12, 18), 'Adventure', 'PG-13', 936662225, 936662225),
#  ('honey, i shrunk the kids', datetime.date(1989, 6, 23), 'Adventure', 'PG', 130724172, 276191669),
#  ('the little mermaid', datetime.date(1989, 11, 15), 'Adventure', 'G', 111543479, 223726012),
#  ('zootopia', datetime.date(2016, 3, 4), 'Adventure', 'PG', 341268248, 341268248),
#  ('the jungle book', datetime.date(2016, 4, 15), 'Adventure', 'PG', 364001123, 364001123),
#  ('finding dory', datetime.date(2016, 6, 17), 'Adventure', 'PG', 486295561, 486295561),
#  ('doctor strange', datetime.date(2016, 11, 4), 'Adventure', 'PG-13', 232532923, 232532923),
#  ('moana', datetime.date(2016, 11, 23), 'Adventure', 'PG', 246082029, 246082029),
#  ('rogue one: a star wars story', datetime.date(2016, 12, 16), 'Adventure', 'PG-13', 529483936, 529483936),
#  ('the princess and the frog', datetime.date(2009, 11, 25), 'Adventure', 'G', 104400899, 116316457),
#  ('alice in wonderland', datetime.date(2010, 3, 5), 'Adventure', 'PG', 334191110, 357063499),
#  ('toy story 3', datetime.date(2010, 6, 18), 'Adventure', 'G', 415004880, 443408255),
#  ('tangled', datetime.date(2010, 11, 24), 'Adventure', 'PG', 200821936, 214388548),
#  ('tron: legacy', datetime.date(2010, 12, 17), 'Adventure', 'PG', 172062763, 183619259),
#  ('brave', datetime.date(2012, 6, 22), 'Adventure', 'PG', 237282182, 251292441),
#  ('wreck-it ralph', datetime.date(2012, 11, 2), 'Adventure', 'PG', 189412677, 200354959),
#  ('oz the great and powerful', datetime.date(2013, 3, 8), 'Adventure', 'PG', 234770996, 243434130),
#  ('monsters university', datetime.date(2013, 6, 21), 'Adventure', 'G', 268488329, 278395641),
#  ('thor: the dark world', datetime.date(2013, 11, 8), 'Adventure', 'PG-13', 206362140, 213962184),
#  ('frozen', datetime.date(2013, 11, 22), 'Adventure', 'PG', 400738009, 414997174),
#  ('maleficent', datetime.date(2014, 5, 30), 'Adventure', 'PG', 241407328, 249089809),
#  ('guardians of the galaxy', datetime.date(2014, 8, 1), 'Adventure', 'PG-13', 333172112, 343771168),
#  ('big hero 6', datetime.date(2014, 11, 7), 'Adventure', 'PG', 222527828, 229249222)]

# %%
# %%sql
# update movie_gross
#     set movie_title = lower(movie_title);
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 579 rows affected.
# []

# %%
# %%sql
# select * from movie_gross limit 5;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 5 rows affected.
# [('amy', datetime.date(1981, 3, 20), 'Drama', None, 0, 0),
#  ('jefferson in paris', datetime.date(1995, 3, 31), 'Drama', 'PG-13', 2461628, 4770461),
#  ('a goofy movie', datetime.date(1995, 4, 7), 'Comedy', 'G', 35336439, 68479579),
#  ('while you were sleeping', datetime.date(1995, 4, 21), 'Romantic Comedy', 'PG', 81057016, 157082900),
#  ('crimson tide', datetime.date(1995, 5, 12), 'Action', 'R', 91387195, 177102077)]

# %% [markdown]
# ## save results

# %%
rs=%sql select * from movie_gross where movie_title ilike '%dog%' limit 5;
rs
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 4 rows affected.
# [('snow dogs', datetime.date(2002, 1, 18), 'Comedy', 'PG', 81150692, 117745317),
#  ('the shaggy dog', datetime.date(2006, 3, 10), 'Comedy', 'PG', 61123569, 78667428),
#  ('underdog', datetime.date(2007, 8, 3), 'Adventure', 'PG', 43760605, 53619462),
#  ('old dogs', datetime.date(2009, 11, 25), 'Comedy', 'PG', 49492060, 55503929)]

# %%
type(rs)
# Out:
# sql.run.ResultSet

# %%
df=rs.DataFrame()
df
# Out:
#       movie_title release_date      genre mpaa_rating  total_gross  \
# 0       snow dogs   2002-01-18     Comedy          PG     81150692
# 1  the shaggy dog   2006-03-10     Comedy          PG     61123569
# 2        underdog   2007-08-03  Adventure          PG     43760605
# 3        old dogs   2009-11-25     Comedy          PG     49492060
#
#    inflation_adjusted_gross
# 0                 117745317
# 1                  78667428
# 2                  53619462
# 3                  55503929

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# %%sql
# select * from movie_gross limit 5;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
# 5 rows affected.
# [('amy', datetime.date(1981, 3, 20), 'Drama', None, 0, 0),
#  ('jefferson in paris', datetime.date(1995, 3, 31), 'Drama', 'PG-13', 2461628, 4770461),
#  ('a goofy movie', datetime.date(1995, 4, 7), 'Comedy', 'G', 35336439, 68479579),
#  ('while you were sleeping', datetime.date(1995, 4, 21), 'Romantic Comedy', 'PG', 81057016, 157082900),
#  ('crimson tide', datetime.date(1995, 5, 12), 'Action', 'R', 91387195, 177102077)]

# %% [markdown]
# ## SqlMagic

# %%
# %config SqlMagic
# Out:
# SqlMagic options
# --------------
# SqlMagic.autocommit=<Bool>
#     Current: True
#     Set autocommit mode
# SqlMagic.autolimit=<Int>
#     Current: 0
#     Automatically limit the size of the returned result sets
# SqlMagic.autopandas=<Bool>
#     Current: False
#     Return Pandas DataFrames instead of regular result sets
# SqlMagic.column_local_vars=<Bool>
#     Current: False
#     Return data into local variables from column names
# SqlMagic.displaycon=<Bool>
#     Current: True
#     Show connection string after execute
# SqlMagic.displaylimit=<Int>
#     Current: None
#     Automatically limit the number of rows displayed (full result set is still
#     stored)
# SqlMagic.dsn_filename=<Unicode>
#     Current: 'odbc.ini'
#     Path to DSN file. When the first argument is of the form [section], a
#     sqlalchemy connection string is formed from the matching section in the DSN
#     file.
# SqlMagic.feedback=<Bool>
#     Current: True
#     Print number of rows affected by DML
# SqlMagic.short_errors=<Bool>
#     Current: True
#     Don't display the full traceback on SQL Programming Error
# SqlMagic.style=<Unicode>
#     Current: 'DEFAULT'
#     Set the table printing style to any of prettytable's defined styles
#     (currently DEFAULT, MSWORD_FRIENDLY, PLAIN_COLUMNS, RANDOM)

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.displaycon = False

# %%
df=%sql select * from movie_gross limit 5;
df
# Out:
# 5 rows affected.
#                movie_title release_date            genre mpaa_rating  \
# 0                      amy   1981-03-20            Drama        None
# 1       jefferson in paris   1995-03-31            Drama       PG-13
# 2            a goofy movie   1995-04-07           Comedy           G
# 3  while you were sleeping   1995-04-21  Romantic Comedy          PG
# 4             crimson tide   1995-05-12           Action           R
#
#    total_gross  inflation_adjusted_gross
# 0            0                         0
# 1      2461628                   4770461
# 2     35336439                  68479579
# 3     81057016                 157082900
# 4     91387195                 177102077

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## multiline %%sql to pandas.DataFrame()

# %%
# %%sql df2 <<
# select *
#     from movie_gross
#     where genre = 'Adventure'
#     limit 5;
# Out:
# 5 rows affected.
# Returning data to local variable df2

# %%
df2
# Out:
#                     movie_title release_date      genre mpaa_rating  \
# 0                    pocahontas   1995-06-10  Adventure           G
# 1          operation dumbo drop   1995-07-28  Adventure          PG
# 2  a kid in king arthur's court   1995-08-11  Adventure          PG
# 3                     toy story   1995-11-22  Adventure           G
# 4                  tom and huck   1995-12-22  Adventure          PG
#
#    total_gross  inflation_adjusted_gross
# 0    141579773                 274370957
# 1     24670346                  47809421
# 2     13406717                  25981285
# 3    191796233                 370409631
# 4     23837227                  45911517

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               5 non-null      object
#  1   release_date              5 non-null      object
#  2   genre                     5 non-null      object
#  3   mpaa_rating               5 non-null      object
#  4   total_gross               5 non-null      int64
#  5   inflation_adjusted_gross  5 non-null      int64
# dtypes: int64(2), object(4)
# memory usage: 368.0+ bytes

# %%
df2['release_date']=df2['release_date'].astype('datetime64')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               5 non-null      object
#  1   release_date              5 non-null      datetime64[ns]
#  2   genre                     5 non-null      object
#  3   mpaa_rating               5 non-null      object
#  4   total_gross               5 non-null      int64
#  5   inflation_adjusted_gross  5 non-null      int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 368.0+ bytes

# %%
df2[df2['release_date'].dt.year == 1993]
# Out:
# Empty DataFrame
# Columns: [movie_title, release_date, genre, mpaa_rating, total_gross, inflation_adjusted_gross]
# Index: []

# %% [markdown]
# ## switch to other database username@dbname

# %%
# %sql \l
# Out:
# 7 rows affected.
#         Name     Owner Encoding     Collate       Ctype  \
# 0    covid19  postgres     UTF8  en_US.utf8  en_US.utf8
# 1       demo  postgres     UTF8  en_US.utf8  en_US.utf8
# 2     disney  postgres     UTF8  en_US.utf8  en_US.utf8
# 3      foody  postgres     UTF8  en_US.utf8  en_US.utf8
# 4   postgres  postgres     UTF8  en_US.utf8  en_US.utf8
# 5  template0  postgres     UTF8  en_US.utf8  en_US.utf8
# 6  template1  postgres     UTF8  en_US.utf8  en_US.utf8
#
#                     Access privileges
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
# 5  =c/postgres\npostgres=CTc/postgres
# 6  =c/postgres\npostgres=CTc/postgres

# %%
dbname='demo'
connection_string=f'postgresql://{user}:{pwd}@{host}:{port}/{dbname}'

# %%
# %config SqlMagic.displaycon = True

# %%
# %sql $connection_string

# %%
# %sql \d
# Out:
#    postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
#  * postgresql://postgres:***@192.168.211.137:5432/demo
# 1 rows affected.
#    Schema       Name   Type     Owner
# 0  public  province2  table  postgres

# %%
# %%sql
# select * from province2 limit 5;
# Out:
#    postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
#  * postgresql://postgres:***@192.168.211.137:5432/demo
# 5 rows affected.
#          name_th         name_en              region destination  household  \
# 0         กระบี่           Krabi                 ใต้   เมืองหลัก     189510
# 1  กรุงเทพมหานคร         Bangkok                กลาง   เมืองหลัก    3041115
# 2      กาญจนบุรี    Kanchanaburi             ตะวันตก   เมืองหลัก     343345
# 3      กาฬสินธุ์         Kalasin  ตะวันออกเฉียงเหนือ    เมืองรอง     305844
# 4      กำแพงเพชร  Kamphaeng Phet                กลาง    เมืองรอง     274543
#
#    population     male   female
# 0      476739   236790   239949
# 1     5666264  2669316  2996948
# 2      895525   450262   445263
# 3      983418   487451   495967
# 4      725867   359205   366662

# %%
# %sql postgres@disney

# %%
# %sql \d
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
#    postgresql://postgres:***@192.168.211.137:5432/demo
# 7 rows affected.
#    Schema          Name   Type     Owner
# 0  public      director  table  postgres
# 1  public   disney_char  table  postgres
# 2  public   movie_gross  table  postgres
# 3  public       revenue  table  postgres
# 4  public   voice_actor  table  postgres
# 5  public     vw_action   view  postgres
# 6  public  vw_adventure   view  postgres

# %%
# %sql select * from disney_char limit 5;
# Out:
#  * postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
#    postgresql://postgres:***@192.168.211.137:5432/demo
# 5 rows affected.
#                        movie_title release_date        hero     villian  \
# 0  Snow White and the Seven Dwarfs   1937-12-21  Snow White  Evil Queen
# 1                        Pinocchio   1940-02-07   Pinocchio   Stromboli
# 2                         Fantasia   1940-11-13        None   Chernabog
# 3                            Dumbo   1941-10-23       Dumbo  Ringmaster
# 4                            Bambi   1942-08-13       Bambi      Hunter
#
#                            song
# 0  Some Day My Prince Will Come
# 1     When You Wish upon a Star
# 2                          None
# 3                     Baby Mine
# 4                Love Is a Song

# %%
# %sql postgres@demo

# %%
# %sql \d
# Out:
#    postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
#  * postgresql://postgres:***@192.168.211.137:5432/demo
# 1 rows affected.
#    Schema       Name   Type     Owner
# 0  public  province2  table  postgres

# %%
# %sql \d province2
# Out:
#    postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
#  * postgresql://postgres:***@192.168.211.137:5432/demo
# 8 rows affected.
#         Column    Type Modifiers
# 0      name_th    text
# 1      name_en    text
# 2       region    text
# 3  destination    text
# 4    household  bigint
# 5   population  bigint
# 6         male  bigint
# 7       female  bigint

# %%
# %%sql
# select * from province2 order by population desc limit 10;
# Out:
#    postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
#  * postgresql://postgres:***@192.168.211.137:5432/demo
# 10 rows affected.
#          name_th              name_en              region destination  \
# 0  กรุงเทพมหานคร              Bangkok                กลาง   เมืองหลัก
# 1     นครราชสีมา    Nakhon Ratchasima  ตะวันออกเฉียงเหนือ   เมืองหลัก
# 2    อุบลราชธานี     Ubon Ratchathani  ตะวันออกเฉียงเหนือ    เมืองรอง
# 3        ขอนแก่น            Khon Kaen  ตะวันออกเฉียงเหนือ   เมืองหลัก
# 4      เชียงใหม่           Chiang Mai               เหนือ   เมืองหลัก
# 5      บุรีรัมย์             Buri Ram  ตะวันออกเฉียงเหนือ    เมืองรอง
# 6       อุดรธานี           Udon Thani  ตะวันออกเฉียงเหนือ    เมืองรอง
# 7  นครศรีธรรมราช  Nakhon Si Thammarat                 ใต้    เมืองรอง
# 8         ชลบุรี            Chon Buri            ตะวันออก   เมืองหลัก
# 9       ศรีสะเกษ            Si Sa Ket  ตะวันออกเฉียงเหนือ    เมืองรอง
#
#    household  population     male   female
# 0    3041115     5666264  2669316  2996948
# 1     983771     2648927  1303944  1344983
# 2     605004     1878146   939054   939092
# 3     628656     1802872   887501   915371
# 4     817820     1779254   861692   917562
# 5     468483     1595747   793262   802485
# 6     519338     1586646   787642   799004
# 7     573215     1561927   771735   790192
# 8    1047473     1558301   762141   796160
# 9     393356     1472859   734405   738454

# %%
# %%sql
# select * into south from province2 where region='ใต้'
# Out:
#    postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
#  * postgresql://postgres:***@192.168.211.137:5432/demo
# 14 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select * from south
# Out:
#    postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
#  * postgresql://postgres:***@192.168.211.137:5432/demo
# 14 rows affected.
#           name_th              name_en region destination  household  \
# 0          กระบี่                Krabi    ใต้   เมืองหลัก     189510
# 1           ชุมพร             Chumphon    ใต้    เมืองรอง     236156
# 2            ตรัง                Trang    ใต้    เมืองรอง     231924
# 3   นครศรีธรรมราช  Nakhon Si Thammarat    ใต้    เมืองรอง     573215
# 4        นราธิวาส           Narathiwat    ใต้    เมืองรอง     215728
# 5         ปัตตานี              Pattani    ใต้    เมืองรอง     191409
# 6           พังงา             Phangnga    ใต้   เมืองหลัก     116485
# 7          พัทลุง          Phatthalung    ใต้    เมืองรอง     194209
# 8          ภูเก็ต               Phuket    ใต้   เมืองหลัก     266093
# 9            ยะลา                 Yala    ใต้    เมืองรอง     167137
# 10          ระนอง               Ranong    ใต้    เมืองรอง      91119
# 11          สงขลา             Songkhla    ใต้   เมืองหลัก     543879
# 12           สตูล                Satun    ใต้    เมืองรอง     104281
# 13   สุราษฎร์ธานี          Surat Thani    ใต้   เมืองหลัก     503053
#
#     population    male  female
# 0       476739  236790  239949
# 1       511304  252854  258450
# 2       643164  314793  328371
# 3      1561927  771735  790192
# 4       808020  400017  408003
# 5       725104  358661  366443
# 6       268788  134192  134596
# 7       524865  255838  269027
# 8       416582  197036  219546
# 9       536330  266860  269470
# 10      193370   97756   95614
# 11     1435968  700441  735527
# 12      323586  160926  162660
# 13     1068010  526693  541317

# %%
# %sql \d
# Out:
#    postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
#  * postgresql://postgres:***@192.168.211.137:5432/demo
# 2 rows affected.
#    Schema       Name   Type     Owner
# 0  public  province2  table  postgres
# 1  public      south  table  postgres

# %%
# %%sql
# drop table south;
# Out:
#    postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
#  * postgresql://postgres:***@192.168.211.137:5432/demo
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %sql \d
# Out:
#    postgresql+psycopg2://postgres:***@192.168.211.137:5432/disney
#  * postgresql://postgres:***@192.168.211.137:5432/demo
# 1 rows affected.
#    Schema       Name   Type     Owner
# 0  public  province2  table  postgres

# %% [markdown]
# ---
